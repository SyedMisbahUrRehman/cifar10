# %%
from keras.datasets import cifar10
from keras.layers import Input, Dense,Conv2D,MaxPooling2D,UpSampling2D,BatchNormalization
from keras.models import Model,Sequential
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.callbacks import History
# %matplotlib inline
(X_train, _), (X_test, _) = cifar10.load_data()
X_train = X_train.astype('float32')/255
X_test = X_test.astype('float32')/255
X_train = X_train.reshape(len(X_train),X_train.shape[1],X_train.shape[2],3)
X_test = X_test.reshape(len(X_test), X_test.shape[1],X_test.shape[2],3)
input_img = Input(shape=(32,32,3))

#Encoder
x = Conv2D(16,(3,3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2,2), padding='same')(x)

x = Conv2D(8,(3,3), activation='relu', padding='same')(x)
x = MaxPooling2D((2,2), padding='same')(x)

x = Conv2D(8,(3,3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2,2), padding='same', name='encoder')(x)

#Decoder
x = Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)

x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)

x = Conv2D(16, (3, 3), activation='relu',padding='same')(x)
x = UpSampling2D((2, 2))(x)

decoded = Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='mse')
model = Sequential()

model.add(Conv2D(32, kernel_size=3, strides=1, padding='same', activation='relu', input_shape=(32, 32, 3)))
model.add(BatchNormalization())     # 32x32x32
model.add(Conv2D(32, kernel_size=3, strides=2, padding='same', activation='relu'))      # 16x16x32
model.add(Conv2D(32, kernel_size=3, strides=1, padding='same', activation='relu'))      # 16x16x32
model.add(BatchNormalization())     # 16x16x32
model.add(UpSampling2D())
model.add(Conv2D(32, kernel_size=3, strides=1, padding='same', activation='relu'))      # 32x32x32
model.add(BatchNormalization())
model.add(Conv2D(3,  kernel_size=1, strides=1, padding='same', activation='sigmoid'))   # 32x32x3

model.compile(optimizer='adam', metrics=['accuracy'], loss='mean_squared_error')
model.summary()
autoencoder=Model(input_img, decoded)
encoder = Model(input_img, encoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = History()

# Train the model and collect accuracy information
model.fit(X_train, X_train,
          epochs=50,
          batch_size=256,
          shuffle=True,
          validation_data=(X_test, X_test),
          callbacks=[history])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_13 (Conv2D)          (None, 32, 32, 32)        896
#
#  batch_normalization_11 (Ba  (None, 32, 32, 32)        128
#  tchNormalization)
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 32)        9248
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 32)        9248
#
#  batch_normalization_12 (Ba  (None, 16, 16, 32)        128
#  tchNormalization)
#
#  up_sampling2d_3 (UpSamplin  (None, 32, 32, 32)        0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 32, 32, 32)        9248
#
#  batch_normalization_13 (Ba  (None, 32, 32, 32)        128
#  tchNormalization)
#
#  conv2d_17 (Conv2D)          (None, 32, 32, 3)         99
#
# =================================================================
# Total params: 29123 (113.76 KB)
# Trainable params: 28931 (113.01 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 196/196 [==============================] - 9s 31ms/step - loss: 0.0075 - accuracy: 0.6667 - val_loss: 0.0331 - val_accuracy: 0.5514
# Epoch 2/50
# 196/196 [==============================] - 5s 23ms/step - loss: 0.0018 - accuracy: 0.7754 - val_loss: 0.0083 - val_accuracy: 0.6744
# Epoch 3/50
# 196/196 [==============================] - 5s 24ms/step - loss: 0.0012 - accuracy: 0.8034 - val_loss: 0.0018 - val_accuracy: 0.8033
# Epoch 4/50
# 196/196 [==============================] - 5s 24ms/step - loss: 9.9846e-04 - accuracy: 0.8211 - val_loss: 0.0012 - val_accuracy: 0.8140
# Epoch 5/50
# 196/196 [==============================] - 5s 23ms/step - loss: 8.4657e-04 - accuracy: 0.8326 - val_loss: 0.0011 - val_accuracy: 0.8342
# Epoch 6/50
# 196/196 [==============================] - 5s 23ms/step - loss: 7.0886e-04 - accuracy: 0.8430 - val_loss: 6.1819e-04 - val_accuracy: 0.8465
# Epoch 7/50
# 196/196 [==============================] - 5s 24ms/step - loss: 6.3396e-04 - accuracy: 0.8502 - val_loss: 6.6241e-04 - val_accuracy: 0.8236
# Epoch 8/50
# 196/196 [==============================] - 5s 23ms/step - loss: 5.7018e-04 - accuracy: 0.8561 - val_loss: 6.4796e-04 - val_accuracy: 0.8556
# Epoch 9/50
# 196/196 [==============================] - 4s 23ms/step - loss: 5.2874e-04 - accuracy: 0.8611 - val_loss: 6.2383e-04 - val_accuracy: 0.8295
# Epoch 10/50
# 196/196 [==============================] - 5s 24ms/step - loss: 4.8336e-04 - accuracy: 0.8645 - val_loss: 5.6440e-04 - val_accuracy: 0.8574
# Epoch 11/50
# 196/196 [==============================] - 4s 23ms/step - loss: 4.5609e-04 - accuracy: 0.8689 - val_loss: 4.5733e-04 - val_accuracy: 0.8252
50
# 196/196 [==============================] - 4s 22ms/step - loss: 2.8568e-04 - accuracy: 0.8931 - val_loss: 2.1589e-04 - val_accuracy: 0.9018
# Epoch 33/50
# 196/196 [==============================] - 5s 25ms/step - loss: 2.7485e-04 - accuracy: 0.8939 - val_loss: 2.9609e-04 - val_accuracy: 0.9066
# Epoch 34/50
# 196/196 [==============================] - 4s 23ms/step - loss: 2.6227e-04 - accuracy: 0.8971 - val_loss: 3.3437e-04 - val_accuracy: 0.8856
# Epoch 35/50
# 196/196 [==============================] - 4s 22ms/step - loss: 2.6772e-04 - accuracy: 0.8959 - val_loss: 3.8222e-04 - val_accuracy: 0.8616
# Epoch 36/50
# 196/196 [==============================] - 5s 25ms/step - loss: 2.6550e-04 - accuracy: 0.8969 - val_loss: 2.9497e-04 - val_accuracy: 0.9006
# Epoch 37/50
# 196/196 [==============================] - 4s 23ms/step - loss: 2.7400e-04 - accuracy: 0.8969 - val_loss: 4.5757e-04 - val_accuracy: 0.9022
# Epoch 38/50
# 196/196 [==============================] - 4s 22ms/step - loss: 2.5480e-04 - accuracy: 0.8974 - val_loss: 6.2351e-04 - val_accuracy: 0.9105
# Epoch 39/50
# 196/196 [==============================] - 5s 24ms/step - loss: 2.4348e-04 - accuracy: 0.8995 - val_loss: 4.8594e-04 - val_accuracy: 0.8762
# Epoch 40/50
# 196/196 [==============================] - 4s 22ms/step - loss: 2.4673e-04 - accuracy: 0.8996 - val_loss: 3.9332e-04 - val_accuracy: 0.8971
# Epoch 41/50
# 196/196 [==============================] - 4s 22ms/step - loss: 2.5198e-04 - accuracy: 0.8998 - val_loss: 1.6105e-04 - val_accuracy: 0.9019
# Epoch 42/50
# 196/196 [==============================] - 5s 24ms/step - loss: 2.4085e-04 - accuracy: 0.8978 - val_loss: 2.6227e-04 - val_accuracy: 0.8920
# Epoch 43/50
# 196/196 [==============================] - 4s 23ms/step - loss: 2.4469e-04 - accuracy: 0.8999 - val_loss: 3.5176e-04 - val_accuracy: 0.8994
# Epoch 44/50
# 196/196 [==============================] - 4s 23ms/step - loss: 2.6130e-04 - accuracy: 0.9000 - val_loss: 3.1302e-04 - val_accuracy: 0.8856
# Epoch 45/50
# 196/196 [==============================] - 5s 24ms/step - loss: 2.3443e-04 - accuracy: 0.9020 - val_loss: 5.8359e-04 - val_accuracy: 0.8676
# Epoch 46/50
# 196/196 [==============================] - 4s 22ms/step - loss: 2.5886e-04 - accuracy: 0.9024 - val_loss: 2.7417e-04 - val_accuracy: 0.8528
# Epoch 47/50
# 196/196 [==============================] - 4s 22ms/step - loss: 2.4217e-04 - accuracy: 0.9048 - val_loss: 4.0807e-04 - val_accuracy: 0.9007
# Epoch 48/50
# 196/196 [==============================] - 5s 24ms/step - loss: 2.2074e-04 - accuracy: 0.9031 - val_loss: 2.1946e-04 - val_accuracy: 0.8769
# Epoch 49/50
# 196/196 [==============================] - 4s 22ms/step - loss: 2.2756e-04 - accuracy: 0.9041 - val_loss: 5.0730e-04 - val_accuracy: 0.8744
# Epoch 50/50
# 196/196 [==============================] - 4s 23ms/step - loss: 2.1203e-04 - accuracy: 0.9032 - val_loss: 2.5150e-04 - val_accuracy: 0.8348

# %%
import matplotlib.pyplot as plt

# Training history from the autoencoder
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

# Plotting the loss curves
plt.plot(training_loss, label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
#encoded_imgs = model.predict(X_test)
predicted = model.predict(X_test)
plt.figure(figsize=(40,4))
for i in range(10):
    # display original images
    ax = plt.subplot(3, 20, i + 1)
    plt.imshow(X_test[i].reshape(32, 32,3))
    #plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)



    # display reconstructed images
    ax = plt.subplot(3, 20, 2*20 +i+ 1)
    plt.imshow(predicted[i].reshape(32, 32,3))
    #plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)


plt.show()
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %%
#Repeat the same architecture in Q1 by replacing the filter (number of kernels in convolution layer) combination to (64,32,16) for encoder part and (16,32,64) for decoder
from keras.datasets import cifar10
from keras.layers import Input, Dense,Conv2D,MaxPooling2D,UpSampling2D,BatchNormalization
from keras.models import Model,Sequential
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.callbacks import History
# %matplotlib inline
(X_train, _), (X_test, _) = cifar10.load_data()
X_train = X_train.astype('float32')/255
X_test = X_test.astype('float32')/255
X_train = X_train.reshape(len(X_train),X_train.shape[1],X_train.shape[2],3)
X_test = X_test.reshape(len(X_test), X_test.shape[1],X_test.shape[2],3)
input_img = Input(shape=(32,32,3))

#Encoder
x = Conv2D(64,(3,3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2,2), padding='same')(x)

x = Conv2D(32,(3,3), activation='relu', padding='same')(x)
x = MaxPooling2D((2,2), padding='same')(x)

x = Conv2D(16,(3,3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2,2), padding='same', name='encoder')(x)

#Decoder
x = Conv2D(16, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)

x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)

x = Conv2D(64, (3, 3), activation='relu',padding='same')(x)
x = UpSampling2D((2, 2))(x)

decoded = Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='mse')
model = Sequential()

model.add(Conv2D(32, kernel_size=3, strides=1, padding='same', activation='relu', input_shape=(32, 32, 3)))
model.add(BatchNormalization())     # 32x32x32
model.add(Conv2D(32, kernel_size=3, strides=2, padding='same', activation='relu'))      # 16x16x32
model.add(Conv2D(32, kernel_size=3, strides=1, padding='same', activation='relu'))      # 16x16x32
model.add(BatchNormalization())     # 16x16x32
model.add(UpSampling2D())
model.add(Conv2D(32, kernel_size=3, strides=1, padding='same', activation='relu'))      # 32x32x32
model.add(BatchNormalization())
model.add(Conv2D(3,  kernel_size=1, strides=1, padding='same', activation='sigmoid'))   # 32x32x3

model.compile(optimizer='adam', metrics=['accuracy'], loss='mean_squared_error')
model.summary()
autoencoder=Model(input_img, decoded)
encoder = Model(input_img, encoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = History()

# Train the model and collect accuracy information
model.fit(X_train, X_train,
          epochs=50,
          batch_size=256,
          shuffle=True,
          validation_data=(X_test, X_test),
          callbacks=[history])
import matplotlib.pyplot as plt

# Training history from the autoencoder
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

# Plotting the loss curves
plt.plot(training_loss, label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

#encoded_imgs = model.predict(X_test)
predicted = model.predict(X_test)
plt.figure(figsize=(40,4))
for i in range(10):
    # display original images
    ax = plt.subplot(3, 20, i + 1)
    plt.imshow(X_test[i].reshape(32, 32,3))
    #plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)



    # display reconstructed images
    ax = plt.subplot(3, 20, 2*20 +i+ 1)
    plt.imshow(predicted[i].reshape(32, 32,3))
    #plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)


plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_25 (Conv2D)          (None, 32, 32, 32)        896
#
#  batch_normalization_14 (Ba  (None, 32, 32, 32)        128
#  tchNormalization)
#
#  conv2d_26 (Conv2D)          (None, 16, 16, 32)        9248
#
#  conv2d_27 (Conv2D)          (None, 16, 16, 32)        9248
#
#  batch_normalization_15 (Ba  (None, 16, 16, 32)        128
#  tchNormalization)
#
#  up_sampling2d_7 (UpSamplin  (None, 32, 32, 32)        0
#  g2D)
#
#  conv2d_28 (Conv2D)          (None, 32, 32, 32)        9248
#
#  batch_normalization_16 (Ba  (None, 32, 32, 32)        128
#  tchNormalization)
#
#  conv2d_29 (Conv2D)          (None, 32, 32, 3)         99
#
# =================================================================
# Total params: 29123 (113.76 KB)
# Trainable params: 28931 (113.01 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 196/196 [==============================] - 9s 27ms/step - loss: 0.0074 - accuracy: 0.6684 - val_loss: 0.0265 - val_accuracy: 0.5106
# Epoch 2/50
# 196/196 [==============================] - 4s 23ms/step - loss: 0.0018 - accuracy: 0.7724 - val_loss: 0.0057 - val_accuracy: 0.6513
# Epoch 3/50
# 196/196 [==============================] - 5s 24ms/step - loss: 0.0012 - accuracy: 0.8032 - val_loss: 0.0015 - val_accuracy: 0.7163
# Epoch 4/50
# 196/196 [==============================] - 4s 23ms/step - loss: 9.5214e-04 - accuracy: 0.8206 - val_loss: 0.0012 - val_accuracy: 0.7359
# Epoch 5/50
# 196/196 [==============================] - 5s 23ms/step - loss: 7.7637e-04 - accuracy: 0.8344 - val_loss: 0.0014 - val_accuracy: 0.7771
# Epoch 6/50
# 196/196 [==============================] - 5s 24ms/step - loss: 6.6409e-04 - accuracy: 0.8448 - val_loss: 7.3183e-04 - val_accuracy: 0.7776
# Epoch 7/50
# 196/196 [==============================] - 5s 26ms/step - loss: 5.8811e-04 - accuracy: 0.8524 - val_loss: 7.6314e-04 - val_accuracy: 0.7625
# Epoch 8/50
# 196/196 [==============================] - 5s 25ms/step - loss: 5.2216e-04 - accuracy: 0.8572 - val_loss: 5.6635e-04 - val_accuracy: 0.8394
# Epoch 9/50
# 196/196 [==============================] - 5s 23ms/step - loss: 4.8646e-04 - accuracy: 0.8647 - val_loss: 4.3446e-04 - val_accuracy: 0.8403
# Epoch 10/50
# 196/196 [==============================] - 4s 23ms/step - loss: 4.5375e-04 - accuracy: 0.8681 - val_loss: 3.9868e-04 - val_accuracy: 0.8636
# Epoch 11/50
50
# 196/196 [==============================] - 4s 23ms/step - loss: 2.8177e-04 - accuracy: 0.8923 - val_loss: 2.5178e-04 - val_accuracy: 0.8764
# Epoch 31/50
# 196/196 [==============================] - 5s 24ms/step - loss: 2.7123e-04 - accuracy: 0.8925 - val_loss: 2.2528e-04 - val_accuracy: 0.8889
# Epoch 32/50
# 196/196 [==============================] - 4s 22ms/step - loss: 2.8620e-04 - accuracy: 0.8948 - val_loss: 3.9770e-04 - val_accuracy: 0.8894
# Epoch 33/50
# 196/196 [==============================] - 4s 23ms/step - loss: 2.7856e-04 - accuracy: 0.8925 - val_loss: 2.1903e-04 - val_accuracy: 0.8797
# Epoch 34/50
# 196/196 [==============================] - 5s 24ms/step - loss: 2.8235e-04 - accuracy: 0.8913 - val_loss: 4.9958e-04 - val_accuracy: 0.8926
# Epoch 35/50
# 196/196 [==============================] - 4s 23ms/step - loss: 2.6103e-04 - accuracy: 0.8938 - val_loss: 2.4453e-04 - val_accuracy: 0.8676
# Epoch 36/50
# 196/196 [==============================] - 4s 22ms/step - loss: 2.5612e-04 - accuracy: 0.8942 - val_loss: 2.7490e-04 - val_accuracy: 0.8741
# Epoch 37/50
# 196/196 [==============================] - 5s 24ms/step - loss: 2.6201e-04 - accuracy: 0.8956 - val_loss: 2.9057e-04 - val_accuracy: 0.8848
# Epoch 38/50
# 196/196 [==============================] - 4s 23ms/step - loss: 2.6850e-04 - accuracy: 0.8950 - val_loss: 3.2528e-04 - val_accuracy: 0.8934
# Epoch 39/50
# 196/196 [==============================] - 4s 23ms/step - loss: 2.6001e-04 - accuracy: 0.8948 - val_loss: 4.1295e-04 - val_accuracy: 0.8220
# Epoch 40/50
# 196/196 [==============================] - 5s 24ms/step - loss: 2.6167e-04 - accuracy: 0.8949 - val_loss: 3.8726e-04 - val_accuracy: 0.8281
# Epoch 41/50
# 196/196 [==============================] - 4s 22ms/step - loss: 2.6391e-04 - accuracy: 0.8972 - val_loss: 4.2123e-04 - val_accuracy: 0.8889
# Epoch 42/50
# 196/196 [==============================] - 4s 22ms/step - loss: 2.4477e-04 - accuracy: 0.8970 - val_loss: 2.3608e-04 - val_accuracy: 0.8476
# Epoch 43/50
# 196/196 [==============================] - 5s 25ms/step - loss: 2.4574e-04 - accuracy: 0.8955 - val_loss: 2.4439e-04 - val_accuracy: 0.8528
# Epoch 44/50
# 196/196 [==============================] - 5s 24ms/step - loss: 2.3941e-04 - accuracy: 0.8960 - val_loss: 2.8014e-04 - val_accuracy: 0.8723
# Epoch 45/50
# 196/196 [==============================] - 4s 23ms/step - loss: 2.4899e-04 - accuracy: 0.8972 - val_loss: 2.0540e-04 - val_accuracy: 0.9034
# Epoch 46/50
# 196/196 [==============================] - 5s 24ms/step - loss: 2.3860e-04 - accuracy: 0.8959 - val_loss: 2.7707e-04 - val_accuracy: 0.8823
# Epoch 47/50
# 196/196 [==============================] - 4s 23ms/step - loss: 2.4488e-04 - accuracy: 0.8964 - val_loss: 2.8013e-04 - val_accuracy: 0.8199
# Epoch 48/50
# 196/196 [==============================] - 4s 23ms/step - loss: 2.3574e-04 - accuracy: 0.8979 - val_loss: 4.0806e-04 - val_accuracy: 0.8645
# Epoch 49/50
# 196/196 [==============================] - 5s 24ms/step - loss: 2.4955e-04 - accuracy: 0.8955 - val_loss: 4.7757e-04 - val_accuracy: 0.8913
# Epoch 50/50
# 196/196 [==============================] - 4s 23ms/step - loss: 2.1554e-04 - accuracy: 0.8998 - val_loss: 3.9452e-04 - val_accuracy: 0.8636
# 313/313 [==============================] - 1s 2ms/step

# %%
#Repeat the same architecture in Q1 by replacing the filter combination to (YOUR CHOICE) for encoder part and (YOUR CHOICE) for decoder.
from keras.datasets import cifar10
from keras.layers import Input, Dense,Conv2D,MaxPooling2D,UpSampling2D,BatchNormalization
from keras.models import Model,Sequential
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.callbacks import History
# %matplotlib inline
(X_train, _), (X_test, _) = cifar10.load_data()
X_train = X_train.astype('float32')/255
X_test = X_test.astype('float32')/255
X_train = X_train.reshape(len(X_train),X_train.shape[1],X_train.shape[2],3)
X_test = X_test.reshape(len(X_test), X_test.shape[1],X_test.shape[2],3)
input_img = Input(shape=(32,32,3))

#Encoder
x = Conv2D(32,(3,3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2,2), padding='same')(x)

x = Conv2D(64,(3,3), activation='relu', padding='same')(x)
x = MaxPooling2D((2,2), padding='same')(x)

x = Conv2D(128,(3,3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2,2), padding='same', name='encoder')(x)

#Decoder
x = Conv2D(128, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)

x = Conv2D(32, (3, 3), activation='relu',padding='same')(x)
x = UpSampling2D((2, 2))(x)

decoded = Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='mse')
model = Sequential()

model.add(Conv2D(32, kernel_size=3, strides=1, padding='same', activation='relu', input_shape=(32, 32, 3)))
model.add(BatchNormalization())     # 32x32x32
model.add(Conv2D(32, kernel_size=3, strides=2, padding='same', activation='relu'))      # 16x16x32
model.add(Conv2D(32, kernel_size=3, strides=1, padding='same', activation='relu'))      # 16x16x32
model.add(BatchNormalization())     # 16x16x32
model.add(UpSampling2D())
model.add(Conv2D(32, kernel_size=3, strides=1, padding='same', activation='relu'))      # 32x32x32
model.add(BatchNormalization())
model.add(Conv2D(3,  kernel_size=1, strides=1, padding='same', activation='sigmoid'))   # 32x32x3

model.compile(optimizer='adam', metrics=['accuracy'], loss='mean_squared_error')
model.summary()
autoencoder=Model(input_img, decoded)
encoder = Model(input_img, encoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = History()

# Train the model and collect accuracy information
model.fit(X_train, X_train,
          epochs=50,
          batch_size=256,
          shuffle=True,
          validation_data=(X_test, X_test),
          callbacks=[history])
import matplotlib.pyplot as plt

# Training history from the autoencoder
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

# Plotting the loss curves
plt.plot(training_loss, label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
#encoded_imgs = model.predict(X_test)
predicted = model.predict(X_test)
plt.figure(figsize=(40,4))
for i in range(10):
    # display original images
    ax = plt.subplot(3, 20, i + 1)
    plt.imshow(X_test[i].reshape(32, 32,3))
    #plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)



    # display reconstructed images
    ax = plt.subplot(3, 20, 2*20 +i+ 1)
    plt.imshow(predicted[i].reshape(32, 32,3))
    #plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)


plt.show()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_37 (Conv2D)          (None, 32, 32, 32)        896
#
#  batch_normalization_17 (Ba  (None, 32, 32, 32)        128
#  tchNormalization)
#
#  conv2d_38 (Conv2D)          (None, 16, 16, 32)        9248
#
#  conv2d_39 (Conv2D)          (None, 16, 16, 32)        9248
#
#  batch_normalization_18 (Ba  (None, 16, 16, 32)        128
#  tchNormalization)
#
#  up_sampling2d_11 (UpSampli  (None, 32, 32, 32)        0
#  ng2D)
#
#  conv2d_40 (Conv2D)          (None, 32, 32, 32)        9248
#
#  batch_normalization_19 (Ba  (None, 32, 32, 32)        128
#  tchNormalization)
#
#  conv2d_41 (Conv2D)          (None, 32, 32, 3)         99
#
# =================================================================
# Total params: 29123 (113.76 KB)
# Trainable params: 28931 (113.01 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 196/196 [==============================] - 7s 28ms/step - loss: 0.0068 - accuracy: 0.6660 - val_loss: 0.0232 - val_accuracy: 0.5730
# Epoch 2/50
# 196/196 [==============================] - 4s 22ms/step - loss: 0.0018 - accuracy: 0.7791 - val_loss: 0.0051 - val_accuracy: 0.6957
# Epoch 3/50
# 196/196 [==============================] - 4s 23ms/step - loss: 0.0012 - accuracy: 0.8059 - val_loss: 0.0013 - val_accuracy: 0.7888
# Epoch 4/50
# 196/196 [==============================] - 5s 23ms/step - loss: 9.2064e-04 - accuracy: 0.8239 - val_loss: 0.0014 - val_accuracy: 0.8169
# Epoch 5/50
# 196/196 [==============================] - 4s 23ms/step - loss: 7.4675e-04 - accuracy: 0.8370 - val_loss: 0.0010 - val_accuracy: 0.8526
# Epoch 6/50
# 196/196 [==============================] - 5s 25ms/step - loss: 6.4265e-04 - accuracy: 0.8471 - val_loss: 6.0118e-04 - val_accuracy: 0.8348
# Epoch 7/50
# 196/196 [==============================] - 5s 23ms/step - loss: 5.7992e-04 - accuracy: 0.8548 - val_loss: 5.5401e-04 - val_accuracy: 0.8359
# Epoch 8/50
# 196/196 [==============================] - 4s 22ms/step - loss: 5.2746e-04 - accuracy: 0.8624 - val_loss: 6.0570e-04 - val_accuracy: 0.8516
# Epoch 9/50
# 196/196 [==============================] - 5s 24ms/step - loss: 4.8848e-04 - accuracy: 0.8667 - val_loss: 4.4793e-04 - val_accuracy: 0.8723
# Epoch 10/50
# 196/196 [==============================] - 4s 23ms/step - loss: 4.4615e-04 - accuracy: 0.8711 - val_loss: 3.5889e-04 - val_accuracy: 0.8778
# Epoch 11/50
# 196/196 [==============================] - 4s 22ms/step - loss: 4.3624e-04 - accuracy: 0.8737 - val_loss: 4.4863e-04 - val_accuracy: 0.8438
# Epoch 12/50
50
# 196/196 [==============================] - 4s 23ms/step - loss: 2.8655e-04 - accuracy: 0.8955 - val_loss: 3.1440e-04 - val_accuracy: 0.8669
# Epoch 34/50
# 196/196 [==============================] - 4s 22ms/step - loss: 2.5545e-04 - accuracy: 0.8962 - val_loss: 2.1396e-04 - val_accuracy: 0.9150
# Epoch 35/50
# 196/196 [==============================] - 5s 24ms/step - loss: 2.5877e-04 - accuracy: 0.8969 - val_loss: 2.3878e-04 - val_accuracy: 0.8781
# Epoch 36/50
# 196/196 [==============================] - 4s 22ms/step - loss: 2.7342e-04 - accuracy: 0.8964 - val_loss: 3.2991e-04 - val_accuracy: 0.8466
# Epoch 37/50
# 196/196 [==============================] - 4s 22ms/step - loss: 2.5980e-04 - accuracy: 0.8992 - val_loss: 2.4291e-04 - val_accuracy: 0.8882
# Epoch 38/50
# 196/196 [==============================] - 5s 24ms/step - loss: 2.5020e-04 - accuracy: 0.8996 - val_loss: 5.0884e-04 - val_accuracy: 0.8937
# Epoch 39/50
# 196/196 [==============================] - 4s 23ms/step - loss: 2.5861e-04 - accuracy: 0.8974 - val_loss: 4.3524e-04 - val_accuracy: 0.8947
# Epoch 40/50
# 196/196 [==============================] - 4s 22ms/step - loss: 2.4040e-04 - accuracy: 0.8999 - val_loss: 2.7809e-04 - val_accuracy: 0.8629
# Epoch 41/50
# 196/196 [==============================] - 5s 24ms/step - loss: 2.5258e-04 - accuracy: 0.8986 - val_loss: 2.1612e-04 - val_accuracy: 0.9151
# Epoch 42/50
# 196/196 [==============================] - 4s 22ms/step - loss: 2.5232e-04 - accuracy: 0.9019 - val_loss: 2.7872e-04 - val_accuracy: 0.8655
# Epoch 43/50
# 196/196 [==============================] - 4s 22ms/step - loss: 2.5196e-04 - accuracy: 0.8998 - val_loss: 4.9914e-04 - val_accuracy: 0.8890
# Epoch 44/50
# 196/196 [==============================] - 5s 24ms/step - loss: 2.5994e-04 - accuracy: 0.9005 - val_loss: 1.9357e-04 - val_accuracy: 0.8873
# Epoch 45/50
# 196/196 [==============================] - 4s 22ms/step - loss: 2.4744e-04 - accuracy: 0.9012 - val_loss: 3.2488e-04 - val_accuracy: 0.8903
# Epoch 46/50
# 196/196 [==============================] - 4s 22ms/step - loss: 2.4688e-04 - accuracy: 0.9016 - val_loss: 2.2746e-04 - val_accuracy: 0.8742
# Epoch 47/50
# 196/196 [==============================] - 5s 24ms/step - loss: 2.5846e-04 - accuracy: 0.9016 - val_loss: 3.8621e-04 - val_accuracy: 0.9166
# Epoch 48/50
# 196/196 [==============================] - 4s 23ms/step - loss: 2.3640e-04 - accuracy: 0.9034 - val_loss: 3.3034e-04 - val_accuracy: 0.8971
# Epoch 49/50
# 196/196 [==============================] - 4s 23ms/step - loss: 2.5891e-04 - accuracy: 0.9020 - val_loss: 1.8588e-04 - val_accuracy: 0.9070
# Epoch 50/50
# 196/196 [==============================] - 5s 23ms/step - loss: 2.4389e-04 - accuracy: 0.9024 - val_loss: 2.6956e-04 - val_accuracy: 0.8713
# 313/313 [==============================] - 1s 2ms/step

# %%
#COMMENT ON BEST AUTOENCODER
#Autoencoder Q1 has a high training and validation accuracy. The training and validation accuracy increases from 50 epochs, indicating that the model is not overfitting, since training and validation accuracy are very close to each other suggests that the model is not underfitting.
#Autoencoder Q2 has a high training and validation accuracy. However, the validation accuracy decreases slightly from epoch 40 to epoch 50, indicating that the model might be slightly overfitting.
#Autoencoder Q3 has a high training and validation accuracy. However, the validation accuracy decreases slightly from epoch 30 to epoch 50, indicating that the model might be slightly overfitting.
#Overall, all three autoencoders perform well on the specific task, with Autoencoder Q3 having the highest training and validation accuracy and due to the differences in validation accuracy between the three models are relatively small, thats wh ythey are having slight changes among them.

# %%
#Denoising Auto Encoder architecture on CIFAR 10 dataset
# importing libraries
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Conv2D, Input, Conv2DTranspose, Activation, BatchNormalization, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, Callback, LearningRateScheduler
from tensorflow.keras.datasets import cifar10
from tensorflow.keras import regularizers
import tensorflow as tf
(train_data_clean, _), (test_data_clean, _) = cifar10.load_data()

# scaling input data
train_data_clean = train_data_clean.astype('float32') / 255.
test_data_clean = test_data_clean.astype('float32') / 255.

def add_noise_and_clip_data(data):
    noise = np.random.normal(loc = 0.0, scale = 0.3, size = data.shape)
    data = data + noise * 0.3
    data = np.clip(data, 0., 1.)
    return data

train_data_noisy = add_noise_and_clip_data(train_data_clean)
test_data_noisy = add_noise_and_clip_data(test_data_clean)
rows = 3 # defining no. of rows in figure
cols = 5 # defining no. of colums in figure

f = plt.figure(figsize = (2 * cols, 2 * rows * 2)) # defining a figure

for i in range(rows):
    for j in range(cols):
        f.add_subplot(rows * 2, cols, (2 * i * cols) + (j + 1)) # adding sub plot to figure on each iteration
        plt.imshow(train_data_noisy[i * cols + j])
        plt.axis("off")

    for j in range(cols):
        f.add_subplot(rows * 2, cols, ((2 * i + 1) * cols) + (j + 1)) # adding sub plot to figure on each iteration
        plt.imshow(train_data_clean[i * cols + j])
        plt.axis("off")

f.suptitle("Sample Training Data", fontsize = 18)
plt.savefig("Cifar-trian.png")

plt.show()
def conv_block(x, filters, kernel_size, strides = 2):
    x = Conv2D(filters = filters,
               kernel_size = kernel_size,
               strides = strides,
               padding = 'same',
               activation = 'relu',
               kernel_regularizer = regularizers.l2(0.001))(x)
    x = BatchNormalization()(x)
    return x

def deconv_block(x, filters, kernel_size):
    x = Conv2DTranspose(filters = filters,
                        kernel_size = kernel_size,
                        strides = 2,
                        padding = 'same',
                        activation = 'relu',
                        kernel_regularizer = regularizers.l2(0.001))(x)
    x = BatchNormalization()(x)
    return x

# %%
def autoencoder():
    inputs = Input(shape = (32, 32, 3), name = 'inputs')
    conv_block1 = conv_block(inputs, 32, 3)
    conv_block2 = conv_block(conv_block1, 64, 3)
    conv_block3 = conv_block(conv_block2, 128, 3)
    conv_block4 = conv_block(conv_block3, 256, 3)
    conv_block5 = conv_block(conv_block4, 256, 3)
    conv_block6 = conv_block(conv_block5, 512, 3, 1)

    deconv_block1 = deconv_block(conv_block6, 512, 3)
    merge1 = Concatenate()([deconv_block1, conv_block4])
    deconv_block2 = deconv_block(merge1, 256, 3)
    merge2 = Concatenate()([deconv_block2, conv_block3])
    deconv_block3 = deconv_block(merge2, 128, 3)
    merge3 = Concatenate()([deconv_block3, conv_block2])
    deconv_block4 = deconv_block(merge3, 64, 3)
    merge4 = Concatenate()([deconv_block4, conv_block1])
    deconv_block5 = deconv_block(merge4, 32, 3)

    final_deconv = Conv2DTranspose(filters = 3, kernel_size = 3, padding = 'same')(deconv_block5)
    outputs = Activation('sigmoid', name = 'output')(final_deconv)
    return Model(inputs, outputs, name = 'autoencoder')
model = autoencoder()

def scheduler(epoch):
    if epoch < 10:
        return 0.0001
    else:
        return 0.0001 * tf.math.exp(0.1 * (10 - epoch))

class myCallback(Callback):
    def on_epoch_end(self, epoch, logs = {}):
        if(logs.get('accuracy') > 0.80):
            print("\nReached 80% accuracy so cancelling training!")
            self.model.stop_training = True

callbacks = myCallback()

lr = LearningRateScheduler(scheduler)
checkpoint = ModelCheckpoint('best_model.h5', verbose = 1, save_best_only = True, save_weights_only = True)

model.compile(optimizer = "adam", loss = 'mse', metrics=["accuracy"])
model.summary()
# Training
history = model.fit(train_data_noisy,
                    train_data_clean,
                    validation_data = (test_data_noisy, test_data_clean),
                    epochs = 25,
                    batch_size = 128,
                    shuffle = True,
                    callbacks = [checkpoint, callbacks, lr])
 # Defining Figure
f = plt.figure(figsize=(10,7))
f.add_subplot()

#Adding Subplot
plt.plot(history.epoch, history.history['loss'], label = "loss") # Loss curve for training set
plt.plot(history.epoch, history.history['val_loss'], label = "val_loss") # Loss curve for validation set

plt.title("Loss Curve",fontsize=18)
plt.xlabel("Epochs",fontsize=15)
plt.ylabel("Loss",fontsize=15)
plt.grid(alpha=0.3)
plt.legend()
plt.savefig("Loss_curve_cifar10.png")
plt.show()
# Out:
# Model: "autoencoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  inputs (InputLayer)         [(None, 32, 32, 3)]          0         []
#
#  conv2d (Conv2D)             (None, 16, 16, 32)           896       ['inputs[0][0]']
#
#  batch_normalization (Batch  (None, 16, 16, 32)           128       ['conv2d[0][0]']
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 64)             18496     ['batch_normalization[0][0]']
#
#  batch_normalization_1 (Bat  (None, 8, 8, 64)             256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 128)            73856     ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  batch_normalization_2 (Bat  (None, 4, 4, 128)            512       ['conv2d_2[0][0]']
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 256)            295168    ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  batch_normalization_3 (Bat  (None, 2, 2, 256)            1024      ['conv2d_3[0][0]']
#  chNormalization)
#
#  conv2d_4 (Conv2D)           (None, 1, 1, 256)            590080    ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  batch_normalization_4 (Bat  (None, 1, 1, 256)            1024      ['conv2d_4[0][0]']
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 1, 1, 512)            1180160   ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  batch_normalization_5 (Bat  (None, 1, 1, 512)            2048      ['conv2d_5[0][0]']
#  chNormalization)
#
#  conv2d_transpose (Conv2DTr  (None, 2, 2, 512)            2359808   ['batch_normalization_5[0][0]'
#  anspose)                                                           ]
#
#  batch_normalization_6 (Bat  (None, 2, 2, 512)            2048      ['conv2d_transpose[0][0]']
#  chNormalization)
#
#  concatenate (Concatenate)   (None, 2, 2, 768)            0         ['batch_normalization_6[0][0]'
#                                                                     , 'batch_normalization_3[0][0]
#                                                                     ']
#
#  conv2d_transpose_1 (Conv2D  (None, 4, 4, 256)            1769728   ['concatenate[0][0]']
#  Transpose)
#
#  batch_normalization_7 (Bat  (None, 4, 4, 256)            1024      ['conv2d_transpose_1[0][0]']
#  chNormalization)
#
#  concatenate_1 (Concatenate  (None, 4, 4, 384)            0         ['batch_normalization_7[0][0]'
#  )                                                                  , 'batch_normalization_2[0][0]
#                                                                     ']
#
#  conv2d_transpose_2 (Conv2D  (None, 8, 8, 128)            442496    ['concatenate_1[0][0]']
#  Transpose)
#
#  batch_normalization_8 (Bat  (None, 8, 8, 128)            512       ['conv2d_transpose_2[0][0]']
#  chNormalization)
#
#  concatenate_2 (Concatenate  (None, 8, 8, 192)            0         ['batch_normalization_8[0][0]'
#  )                                                                  , 'batch_normalization_1[0][0]
#                                                                     ']
#
#  conv2d_transpose_3 (Conv2D  (None, 16, 16, 64)           110656    ['concatenate_2[0][0]']
#  Transpose)
#
#  batch_normalization_9 (Bat  (None, 16, 16, 64)           256       ['conv2d_transpose_3[0][0]']
#  chNormalization)
#
#  concatenate_3 (Concatenate  (None, 16, 16, 96)           0         ['batch_normalization_9[0][0]'
#  )                                                                  , 'batch_normalization[0][0]']
#
#  conv2d_transpose_4 (Conv2D  (None, 32, 32, 32)           27680     ['concatenate_3[0][0]']
#  Transpose)
#
#  batch_normalization_10 (Ba  (None, 32, 32, 32)           128       ['conv2d_transpose_4[0][0]']
#  tchNormalization)
#
#  conv2d_transpose_5 (Conv2D  (None, 32, 32, 3)            867       ['batch_normalization_10[0][0]
#  Transpose)                                                         ']
#
#  output (Activation)         (None, 32, 32, 3)            0         ['conv2d_transpose_5[0][0]']
#
# ==================================================================================================
# Total params: 6878851 (26.24 MB)
# Trainable params: 6874371 (26.22 MB)
# Non-trainable params: 4480 (17.50 KB)
# __________________________________________________________________________________________________
# Epoch 1/25
# 391/391 [==============================] - ETA: 0s - loss: 0.6221 - accuracy: 0.5477
# Epoch 1: val_loss improved from inf to 0.10685, saving model to best_model.h5
# 391/391 [==============================] - 36s 53ms/step - loss: 0.6221 - accuracy: 0.5477 - val_loss: 0.1069 - val_accuracy: 0.5638 - lr: 1.0000e-04
# Epoch 2/25
# 391/391 [==============================] - ETA: 0s - loss: 0.0447 - accuracy: 0.6914
# Epoch 2: val_loss improved from 0.10685 to 0.02311, saving model to best_model.h5
# 391/391 [==============================] - 16s 42ms/step - loss: 0.0447 - accuracy: 0.6914 - val_loss: 0.0231 - val_accuracy: 0.7104 - lr: 1.0000e-04
# Epoch 3/25
# 391/391 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.7374
# Epoch 3: val_loss improved from 0.02311 to 0.01147, saving model to best_model.h5
# 391/391 [==============================] - 18s 45ms/step - loss: 0.0139 - accuracy: 0.7374 - val_loss: 0.0115 - val_accuracy: 0.7435 - lr: 1.0000e-04
# Epoch 4/25
# 391/391 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.7562
# Epoch 4: val_loss improved from 0.01147 to 0.00797, saving model to best_model.h5
# 391/391 [==============================] - 17s 44ms/step - loss: 0.0081 - accuracy: 0.7562 - val_loss: 0.0080 - val_accuracy: 0.7767 - lr: 1.0000e-04
# Epoch 5/25
# 391/391 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.7692
# Epoch 5: val_loss improved from 0.00797 to 0.00573, saving model to best_model.h5
# 391/391 [==============================] - 18s 46ms/step - loss: 0.0052 - accuracy: 0.7692 - val_loss: 0.0057 - val_accuracy: 0.7677 - lr: 1.0000e-04
# Epoch 6/25
# 391/391 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.7740
# Epoch 6: val_loss improved from 0.00573 to 0.00555, saving model to best_model.h5
# 391/391 [==============================] - 18s 47ms/step - loss: 0.0038 - accuracy: 0.7740 - val_loss: 0.0056 - val_accuracy: 0.7697 - lr: 1.0000e-04
# Epoch 7/25
# 391/391 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.7775
# Epoch 7: val_loss improved from 0.00555 to 0.00470, saving model to best_model.h5
# 391/391 [==============================] - 19s 47ms/step - loss: 0.0030 - accuracy: 0.7775 - val_loss: 0.0047 - val_accuracy: 0.7807 - lr: 1.0000e-04
# Epoch 8/25
# 391/391 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.7819
# Epoch 8: val_loss improved from 0.00470 to 0.00368, saving model to best_model.h5
# 391/391 [==============================] - 17s 44ms/step - loss: 0.0026 - accuracy: 0.7819 - val_loss: 0.0037 - val_accuracy: 0.7685 - lr: 1.0000e-04
# Epoch 9/25
# 391/391 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.7882
# Epoch 9: val_loss improved from 0.00368 to 0.00361, saving model to best_model.h5
# 391/391 [==============================] - 18s 46ms/step - loss: 0.0023 - accuracy: 0.7882 - val_loss: 0.0036 - val_accuracy: 0.7904 - lr: 1.0000e-04
# Epoch 10/25
# 391/391 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.7923
# Epoch 10: val_loss improved from 0.00361 to 0.00196, saving model to best_model.h5
# 391/391 [==============================] - 18s 47ms/step - loss: 0.0021 - accuracy: 0.7923 - val_loss: 0.0020 - val_accuracy: 0.7960 - lr: 1.0000e-04
# Epoch 11/25
# 391/391 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.7947
# Epoch 11: val_loss did not improve from 0.00196
# 391/391 [==============================] - 17s 44ms/step - loss: 0.0020 - accuracy: 0.7947 - val_loss: 0.0020 - val_accuracy: 0.7948 - lr: 1.0000e-04
# Epoch 12/25
# 391/391 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.7956
# Epoch 12: val_loss improved from 0.00196 to 0.00181, saving model to best_model.h5
# 391/391 [==============================] - 18s 47ms/step - loss: 0.0019 - accuracy: 0.7956 - val_loss: 0.0018 - val_accuracy: 0.7905 - lr: 9.0484e-05
# Epoch 13/25
# 391/391 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.7980
# Epoch 13: val_loss improved from 0.00181 to 0.00174, saving model to best_model.h5
# 391/391 [==============================] - 17s 44ms/step - loss: 0.0019 - accuracy: 0.7980 - val_loss: 0.0017 - val_accuracy: 0.8038 - lr: 8.1873e-05
# Epoch 14/25
# 391/391 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.8004
# Epoch 14: val_loss improved from 0.00174 to 0.00171, saving model to best_model.h5
#
# Reached 80% accuracy so cancelling training!
# 391/391 [==============================] - 18s 46ms/step - loss: 0.0019 - accuracy: 0.8004 - val_loss: 0.0017 - val_accuracy: 0.8080 - lr: 7.4082e-05

# %%
# Select few random test images
num_imgs = 48
rand = np.random.randint(1, test_data_noisy.shape[0]-48)

cifar_test_images = test_data_noisy[rand:rand+num_imgs] # slicing
cifar_test_predicted = model.predict(cifar_test_images) # predict
rows = 4 # defining no. of rows in figure
cols = 12 # defining no. of colums in figure
cell_size = 1.5
f = plt.figure(figsize=(cell_size*cols,cell_size*rows*2)) # defining a figure
f.tight_layout()
for i in range(rows):
    for j in range(cols):
        f.add_subplot(rows * 2, cols, (2 * i * cols) + (j + 1)) # adding sub plot to figure on each iteration
        plt.imshow(cifar_test_images[i * cols + j])
        plt.axis("off")

    for j in range(cols):
        f.add_subplot(rows * 2, cols, ((2 * i+ 1) * cols) + (j + 1)) # adding sub plot to figure on each iteration
        plt.imshow(cifar_test_predicted[i * cols + j])
        plt.axis("off")

f.suptitle("Autoencoder Results - Cifar10",fontsize=18)
plt.savefig("test_results_cifar10.png")

plt.show()
# Out:
# 2/2 [==============================] - 3s 18ms/step

# %%
#Change the noise parameters in ‘add_noise_and_clip_data’ function to YOUR CHOICE
#    noise = np.random.normal(loc = 0.0, scale = 0.1, size = data.shape)  data = data + noise * 0.5
# importing libraries
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Conv2D, Input, Conv2DTranspose, Activation, BatchNormalization, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, Callback, LearningRateScheduler
from tensorflow.keras.datasets import cifar10
from tensorflow.keras import regularizers
import tensorflow as tf
(train_data_clean, _), (test_data_clean, _) = cifar10.load_data()

# scaling input data
train_data_clean = train_data_clean.astype('float32') / 255.
test_data_clean = test_data_clean.astype('float32') / 255.

def add_noise_and_clip_data(data):
    noise = np.random.normal(loc = 0.0, scale = 0.3, size = data.shape)
    data = data + noise * 0.3
    data = np.clip(data, 0., 1.)
    return data

train_data_noisy = add_noise_and_clip_data(train_data_clean)
test_data_noisy = add_noise_and_clip_data(test_data_clean)

def add_noise_and_clip_data(data):
    noise = np.random.normal(loc = 0.0, scale = 0.1, size = data.shape)
    data = data + noise * 0.5
    data = np.clip(data, 0., 1.)
    return data

train_data_noisy = add_noise_and_clip_data(train_data_clean)
test_data_noisy = add_noise_and_clip_data(test_data_clean)
rows = 3 # defining no. of rows in figure
cols = 5 # defining no. of colums in figure

f = plt.figure(figsize = (2 * cols, 2 * rows * 2)) # defining a figure

for i in range(rows):
    for j in range(cols):
        f.add_subplot(rows * 2, cols, (2 * i * cols) + (j + 1)) # adding sub plot to figure on each iteration
        plt.imshow(train_data_noisy[i * cols + j])
        plt.axis("off")

    for j in range(cols):
        f.add_subplot(rows * 2, cols, ((2 * i + 1) * cols) + (j + 1)) # adding sub plot to figure on each iteration
        plt.imshow(train_data_clean[i * cols + j])
        plt.axis("off")

f.suptitle("Sample Training Data", fontsize = 18)
plt.savefig("Cifar-trian.png")

plt.show()
def conv_block(x, filters, kernel_size, strides = 2):
    x = Conv2D(filters = filters,
               kernel_size = kernel_size,
               strides = strides,
               padding = 'same',
               activation = 'relu',
               kernel_regularizer = regularizers.l2(0.001))(x)
    x = BatchNormalization()(x)
    return x

def deconv_block(x, filters, kernel_size):
    x = Conv2DTranspose(filters = filters,
                        kernel_size = kernel_size,
                        strides = 2,
                        padding = 'same',
                        activation = 'relu',
                        kernel_regularizer = regularizers.l2(0.001))(x)
    x = BatchNormalization()(x)
    return x

def autoencoder():
    inputs = Input(shape = (32, 32, 3), name = 'inputs')
    conv_block1 = conv_block(inputs, 32, 3)
    conv_block2 = conv_block(conv_block1, 64, 3)
    conv_block3 = conv_block(conv_block2, 128, 3)
    conv_block4 = conv_block(conv_block3, 256, 3)
    conv_block5 = conv_block(conv_block4, 256, 3)
    conv_block6 = conv_block(conv_block5, 512, 3, 1)

    deconv_block1 = deconv_block(conv_block6, 512, 3)
    merge1 = Concatenate()([deconv_block1, conv_block4])
    deconv_block2 = deconv_block(merge1, 256, 3)
    merge2 = Concatenate()([deconv_block2, conv_block3])
    deconv_block3 = deconv_block(merge2, 128, 3)
    merge3 = Concatenate()([deconv_block3, conv_block2])
    deconv_block4 = deconv_block(merge3, 64, 3)
    merge4 = Concatenate()([deconv_block4, conv_block1])
    deconv_block5 = deconv_block(merge4, 32, 3)

    final_deconv = Conv2DTranspose(filters = 3, kernel_size = 3, padding = 'same')(deconv_block5)
    outputs = Activation('sigmoid', name = 'output')(final_deconv)
    return Model(inputs, outputs, name = 'autoencoder')
model = autoencoder()

def scheduler(epoch):
    if epoch < 10:
        return 0.0001
    else:
        return 0.0001 * tf.math.exp(0.1 * (10 - epoch))

class myCallback(Callback):
    def on_epoch_end(self, epoch, logs = {}):
        if(logs.get('accuracy') > 0.80):
            print("\nReached 80% accuracy so cancelling training!")
            self.model.stop_training = True

callbacks = myCallback()

lr = LearningRateScheduler(scheduler)
checkpoint = ModelCheckpoint('best_model.h5', verbose = 1, save_best_only = True, save_weights_only = True)

model.compile(optimizer = "adam", loss = 'mse', metrics=["accuracy"])
model.summary()
# Training
history = model.fit(train_data_noisy,
                    train_data_clean,
                    validation_data = (test_data_noisy, test_data_clean),
                    epochs = 25,
                    batch_size = 128,
                    shuffle = True,
                    callbacks = [checkpoint, callbacks, lr])
 # Defining Figure
f = plt.figure(figsize=(10,7))
f.add_subplot()

#Adding Subplot
plt.plot(history.epoch, history.history['loss'], label = "loss") # Loss curve for training set
plt.plot(history.epoch, history.history['val_loss'], label = "val_loss") # Loss curve for validation set

plt.title("Loss Curve",fontsize=18)
plt.xlabel("Epochs",fontsize=15)
plt.ylabel("Loss",fontsize=15)
plt.grid(alpha=0.3)
plt.legend()
plt.savefig("Loss_curve_cifar10.png")
plt.show()
# Out:
# Model: "autoencoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  inputs (InputLayer)         [(None, 32, 32, 3)]          0         []
#
#  conv2d (Conv2D)             (None, 16, 16, 32)           896       ['inputs[0][0]']
#
#  batch_normalization (Batch  (None, 16, 16, 32)           128       ['conv2d[0][0]']
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 64)             18496     ['batch_normalization[0][0]']
#
#  batch_normalization_1 (Bat  (None, 8, 8, 64)             256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 128)            73856     ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  batch_normalization_2 (Bat  (None, 4, 4, 128)            512       ['conv2d_2[0][0]']
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 256)            295168    ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  batch_normalization_3 (Bat  (None, 2, 2, 256)            1024      ['conv2d_3[0][0]']
#  chNormalization)
#
#  conv2d_4 (Conv2D)           (None, 1, 1, 256)            590080    ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  batch_normalization_4 (Bat  (None, 1, 1, 256)            1024      ['conv2d_4[0][0]']
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 1, 1, 512)            1180160   ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  batch_normalization_5 (Bat  (None, 1, 1, 512)            2048      ['conv2d_5[0][0]']
#  chNormalization)
#
#  conv2d_transpose (Conv2DTr  (None, 2, 2, 512)            2359808   ['batch_normalization_5[0][0]'
#  anspose)                                                           ]
#
#  batch_normalization_6 (Bat  (None, 2, 2, 512)            2048      ['conv2d_transpose[0][0]']
#  chNormalization)
#
#  concatenate (Concatenate)   (None, 2, 2, 768)            0         ['batch_normalization_6[0][0]'
#                                                                     , 'batch_normalization_3[0][0]
#                                                                     ']
#
#  conv2d_transpose_1 (Conv2D  (None, 4, 4, 256)            1769728   ['concatenate[0][0]']
#  Transpose)
#
#  batch_normalization_7 (Bat  (None, 4, 4, 256)            1024      ['conv2d_transpose_1[0][0]']
#  chNormalization)
#
#  concatenate_1 (Concatenate  (None, 4, 4, 384)            0         ['batch_normalization_7[0][0]'
#  )                                                                  , 'batch_normalization_2[0][0]
#                                                                     ']
#
#  conv2d_transpose_2 (Conv2D  (None, 8, 8, 128)            442496    ['concatenate_1[0][0]']
#  Transpose)
#
#  batch_normalization_8 (Bat  (None, 8, 8, 128)            512       ['conv2d_transpose_2[0][0]']
#  chNormalization)
#
#  concatenate_2 (Concatenate  (None, 8, 8, 192)            0         ['batch_normalization_8[0][0]'
#  )                                                                  , 'batch_normalization_1[0][0]
#                                                                     ']
#
#  conv2d_transpose_3 (Conv2D  (None, 16, 16, 64)           110656    ['concatenate_2[0][0]']
#  Transpose)
#
#  batch_normalization_9 (Bat  (None, 16, 16, 64)           256       ['conv2d_transpose_3[0][0]']
#  chNormalization)
#
#  concatenate_3 (Concatenate  (None, 16, 16, 96)           0         ['batch_normalization_9[0][0]'
#  )                                                                  , 'batch_normalization[0][0]']
#
#  conv2d_transpose_4 (Conv2D  (None, 32, 32, 32)           27680     ['concatenate_3[0][0]']
#  Transpose)
#
#  batch_normalization_10 (Ba  (None, 32, 32, 32)           128       ['conv2d_transpose_4[0][0]']
#  tchNormalization)
#
#  conv2d_transpose_5 (Conv2D  (None, 32, 32, 3)            867       ['batch_normalization_10[0][0]
#  Transpose)                                                         ']
#
#  output (Activation)         (None, 32, 32, 3)            0         ['conv2d_transpose_5[0][0]']
#
# ==================================================================================================
# Total params: 6878851 (26.24 MB)
# Trainable params: 6874371 (26.22 MB)
# Non-trainable params: 4480 (17.50 KB)
# __________________________________________________________________________________________________
# Epoch 1/25
# 391/391 [==============================] - ETA: 0s - loss: 0.6220 - accuracy: 0.5605
# Epoch 1: val_loss improved from inf to 0.10503, saving model to best_model.h5
# 391/391 [==============================] - 34s 53ms/step - loss: 0.6220 - accuracy: 0.5605 - val_loss: 0.1050 - val_accuracy: 0.5375 - lr: 1.0000e-04
# Epoch 2/25
# 391/391 [==============================] - ETA: 0s - loss: 0.0422 - accuracy: 0.7128
# Epoch 2: val_loss improved from 0.10503 to 0.02083, saving model to best_model.h5
# 391/391 [==============================] - 18s 45ms/step - loss: 0.0422 - accuracy: 0.7128 - val_loss: 0.0208 - val_accuracy: 0.6706 - lr: 1.0000e-04
# Epoch 3/25
# 390/391 [============================>.] - ETA: 0s - loss: 0.0115 - accuracy: 0.7681
# Epoch 3: val_loss did not improve from 0.02083
# 391/391 [==============================] - 17s 44ms/step - loss: 0.0115 - accuracy: 0.7681 - val_loss: 0.0273 - val_accuracy: 0.6563 - lr: 1.0000e-04
# Epoch 4/25
# 391/391 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.7930
# Epoch 4: val_loss improved from 0.02083 to 0.00632, saving model to best_model.h5
# 391/391 [==============================] - 17s 45ms/step - loss: 0.0055 - accuracy: 0.7930 - val_loss: 0.0063 - val_accuracy: 0.6854 - lr: 1.0000e-04
# Epoch 5/25
# 390/391 [============================>.] - ETA: 0s - loss: 0.0033 - accuracy: 0.8031
# Epoch 5: val_loss improved from 0.00632 to 0.00498, saving model to best_model.h5
#
# Reached 80% accuracy so cancelling training!
# 391/391 [==============================] - 19s 48ms/step - loss: 0.0033 - accuracy: 0.8031 - val_loss: 0.0050 - val_accuracy: 0.7040 - lr: 1.0000e-04
